# %% [markdown]
# # 3. Preprocessing

# %% [markdown]
# 1. Importing packages and dataset
# 2. Categorical to cardinal transformation
# 3. Feature scaling

# %% [markdown]
# ## 3.1. Importing packages and dataset

# %%
# Import the required packages

import os
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedShuffleSplit

import warnings
warnings.filterwarnings("ignore")

# %%
# Import pre-processed dataset and load it into a dataframe

# Create path variable
original_file = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/interim/category_transformation.csv'

# Load csv in dataframe
dfo = pd.read_csv(original_file, index_col=0)

# %%
# Check # of columns and rows imported
dfo.shape
# Out:
# (78547, 37)

# %%
# Print info
dfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78547 entries, 0 to 79329
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   LeadTime                     78547 non-null  float64
#  1   ArrivalDateYear              78547 non-null  int64
#  2   ArrivalDateMonth             78547 non-null  object
#  3   ArrivalDateWeekNumber        78547 non-null  int64
#  4   ArrivalDateDayOfMonth        78547 non-null  int64
#  5   StaysInWeekendNights         78547 non-null  object
#  6   StaysInWeekNights            78547 non-null  object
#  7   Adults                       78547 non-null  float64
#  8   Children                     78547 non-null  float64
#  9   Babies                       78547 non-null  float64
#  10  Meal                         78547 non-null  object
#  11  Country                      78547 non-null  object
#  12  MarketSegment                78547 non-null  object
#  13  DistributionChannel          78547 non-null  object
#  14  IsRepeatedGuest              78547 non-null  int64
#  15  PreviousCancellations        78547 non-null  object
#  16  PreviousBookingsNotCanceled  78547 non-null  object
#  17  ReservedRoomType             78547 non-null  object
#  18  AssignedRoomType             78547 non-null  object
#  19  BookingChanges               78547 non-null  object
#  20  DepositType                  78547 non-null  object
#  21  Agent                        78547 non-null  object
#  22  Company                      78547 non-null  object
#  23  DaysInWaitingList            78547 non-null  float64
#  24  CustomerType                 78547 non-null  object
#  25  ADR                          78547 non-null  float64
#  26  RequiredCarParkingSpaces     78547 non-null  int64
#  27  TotalOfSpecialRequests       78547 non-null  object
#  28  ReservationStatus            78547 non-null  object
#  29  ReservationStatusDate        78547 non-null  object
#  30  ArrivalDate                  78547 non-null  object
#  31  ReservationDate              78547 non-null  object
#  32  ChangedRoom                  78547 non-null  int64
#  33  TotalStay                    78547 non-null  float64
#  34  CheckOutDate                 78547 non-null  object
#  35  StayChanges                  78547 non-null  object
#  36  ReservationMonth             78547 non-null  object
# dtypes: float64(7), int64(6), object(24)
# memory usage: 22.8+ MB

# %%
# Converts all non float variables in categorical
cat_cols = dfo.select_dtypes(exclude='float64').columns
dfo[cat_cols] = dfo[cat_cols].astype('category')

# Convert variables to categorical
dfo['Adults'] = dfo['Adults'].astype('category')
dfo['Children'] = dfo['Children'].astype('category')
dfo['Babies'] = dfo['Babies'].astype('category')

# %% [markdown]
# ## 3.2. Sample selection

# %%
# Creates variable exclusion list for modeling
to_drop = ['ReservationDate', 'ReservationStatusDate', 'CheckOutDate', 
           'ArrivalDate', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth', 
           'ArrivalDateYear', 'AssignedRoomType', 'DaysInWaitingList', 'TotalStay']

# Removes features
dfo.drop(to_drop, axis=1, inplace=True)

# %%
X = dfo.drop(['ArrivalDateMonth'], axis=1)
y = dfo['ArrivalDateMonth']

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=10)
split = sss.split(X, y)

for train_index, test_index in split:
    sample_df = dfo.iloc[test_index]

# %%
sample_df.shape
# Out:
# (15710, 27)

# %% [markdown]
# ## 3.2. Categorical to cardinal transformation

# %%
# Get dummy variables for each categorical variable
encoded_df = pd.get_dummies(sample_df, drop_first=True)

# Check number of total variables
encoded_df.shape
# Out:
# (15710, 91)

# %% [markdown]
# ## 3.3. Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(encoded_df)
scaled = scaler.transform(encoded_df)

# %%
df_scaled = pd.DataFrame(scaled, columns=encoded_df.columns)

# %%
df_scaled.sample(10)
# Out:
#        LeadTime       ADR  ArrivalDateMonth_August  ArrivalDateMonth_December  \
# 13236 -0.944162  2.331531                 2.799245                  -0.234822
# 11214  3.232629  0.178578                -0.357239                  -0.234822
# 1940  -0.058176  0.498458                -0.357239                  -0.234822
# 4615  -0.998406 -0.173214                -0.357239                  -0.234822
# 15704 -0.998406  0.367212                -0.357239                  -0.234822
# 116   -0.582535 -0.682758                -0.357239                  -0.234822
# 1794   0.936298 -0.008513                -0.357239                  -0.234822
# 7374  -0.853756  2.769019                -0.357239                  -0.234822
# 7570   1.867488  0.367212                -0.357239                  -0.234822
# 14877 -0.383641 -1.125393                -0.357239                  -0.234822
#
#        ArrivalDateMonth_February  ArrivalDateMonth_January  \
# 13236                  -0.258917                 -0.222963
# 11214                  -0.258917                 -0.222963
# 1940                   -0.258917                 -0.222963
# 4615                    3.862243                 -0.222963
# 15704                  -0.258917                 -0.222963
# 116                     3.862243                 -0.222963
# 1794                   -0.258917                 -0.222963
# 7374                   -0.258917                 -0.222963
# 7570                   -0.258917                 -0.222963
# 14877                  -0.258917                 -0.222963
#
#        ArrivalDateMonth_July  ArrivalDateMonth_June  ArrivalDateMonth_March  \
# 13236              -0.335686              -0.332862               -0.297325
# 11214               2.978975              -0.332862               -0.297325
# 1940               -0.335686              -0.332862               -0.297325
# 4615               -0.335686              -0.332862               -0.297325
# 15704              -0.335686              -0.332862               -0.297325
# 116                -0.335686              -0.332862               -0.297325
# 1794               -0.335686              -0.332862               -0.297325
# 7374               -0.335686               3.004251               -0.297325
# 7570               -0.335686              -0.332862               -0.297325
# 14877              -0.335686              -0.332862               -0.297325
#
#        ArrivalDateMonth_May  ...  ReservationMonth_December  \
# 13236             -0.339896  ...                  -0.298718
# 11214             -0.339896  ...                  -0.298718
# 1940              -0.339896  ...                  -0.298718
# 4615              -0.339896  ...                  -0.298718
# 15704             -0.339896  ...                  -0.298718
# 116               -0.339896  ...                   3.347638
# 1794              -0.339896  ...                  -0.298718
# 7374              -0.339896  ...                  -0.298718
# 7570              -0.339896  ...                  -0.298718
# 14877             -0.339896  ...                  -0.298718
#
#        ReservationMonth_February  ReservationMonth_January  \
# 13236                  -0.359727                 -0.400546
# 11214                  -0.359727                 -0.400546
# 1940                   -0.359727                 -0.400546
# 4615                    2.779888                 -0.400546
# 15704                  -0.359727                 -0.400546
# 116                    -0.359727                 -0.400546
# 1794                   -0.359727                 -0.400546
# 7374                   -0.359727                 -0.400546
# 7570                   -0.359727                 -0.400546
# 14877                  -0.359727                 -0.400546
#
#        ReservationMonth_July  ReservationMonth_June  ReservationMonth_March  \
# 13236              -0.311187              -0.209909               -0.296691
# 11214              -0.311187              -0.209909               -0.296691
# 1940                3.213503              -0.209909               -0.296691
# 4615               -0.311187              -0.209909               -0.296691
# 15704              -0.311187              -0.209909               -0.296691
# 116                -0.311187              -0.209909               -0.296691
# 1794               -0.311187              -0.209909                3.370511
# 7374               -0.311187              -0.209909               -0.296691
# 7570               -0.311187              -0.209909               -0.296691
# 14877               3.213503              -0.209909               -0.296691
#
#        ReservationMonth_May  ReservationMonth_November  \
# 13236             -0.253983                  -0.296691
# 11214             -0.253983                  -0.296691
# 1940              -0.253983                  -0.296691
# 4615              -0.253983                  -0.296691
# 15704             -0.253983                  -0.296691
# 116               -0.253983                  -0.296691
# 1794              -0.253983                  -0.296691
# 7374               3.937271                  -0.296691
# 7570              -0.253983                   3.370511
# 14877             -0.253983                  -0.296691
#
#        ReservationMonth_October  ReservationMonth_September
# 13236                 -0.336741                   -0.267899
# 11214                 -0.336741                   -0.267899
# 1940                  -0.336741                   -0.267899
# 4615                  -0.336741                   -0.267899
# 15704                  2.969638                   -0.267899
# 116                   -0.336741                   -0.267899
# 1794                  -0.336741                   -0.267899
# 7374                  -0.336741                   -0.267899
# 7570                  -0.336741                   -0.267899
# 14877                 -0.336741                   -0.267899
#
# [10 rows x 91 columns]

# %% [markdown]
# ---
# The resulting dataframe is loaded in a csv file for further steps in a different notebook.

# %%
# Writing df dataframe to csv

path1 = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/processed/preprocessed.csv'
path2 = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/processed/non_preprocessed.csv'

df_scaled.to_csv(path1)
sample_df.to_csv(path2)

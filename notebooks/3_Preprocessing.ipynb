# %% [markdown]
# # 3. Preprocessing

# %% [markdown]
# 1. Importing packages and dataset
# 2. Categorical to cardinal transformation
# 3. Feature scaling

# %% [markdown]
# ## 3.1. Importing packages and dataset

# %%
# Import the required packages

import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# Import pre-processed dataset and load it into a dataframe

# Create path variable
original_file = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/interim/category_transformation.csv'

# Load csv in dataframe
dfo = pd.read_csv(original_file, index_col=0)

# %%
# Check # of columns and rows imported
dfo.shape
# Out:
# (79120, 37)

# %%
# Print info
dfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79120 entries, 0 to 79329
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   LeadTime                     79120 non-null  float64
#  1   ArrivalDateYear              79120 non-null  int64
#  2   ArrivalDateMonth             79120 non-null  object
#  3   ArrivalDateWeekNumber        79120 non-null  int64
#  4   ArrivalDateDayOfMonth        79120 non-null  int64
#  5   StaysInWeekendNights         79120 non-null  object
#  6   StaysInWeekNights            79120 non-null  object
#  7   Adults                       79120 non-null  float64
#  8   Children                     79120 non-null  float64
#  9   Babies                       79120 non-null  float64
#  10  Meal                         79120 non-null  object
#  11  Country                      79120 non-null  object
#  12  MarketSegment                79120 non-null  object
#  13  DistributionChannel          79120 non-null  object
#  14  IsRepeatedGuest              79120 non-null  int64
#  15  PreviousCancellations        79120 non-null  object
#  16  PreviousBookingsNotCanceled  79120 non-null  object
#  17  ReservedRoomType             79120 non-null  object
#  18  AssignedRoomType             79120 non-null  object
#  19  BookingChanges               79120 non-null  object
#  20  DepositType                  79120 non-null  object
#  21  Agent                        71045 non-null  object
#  22  Company                      3663 non-null   object
#  23  DaysInWaitingList            79120 non-null  float64
#  24  CustomerType                 79120 non-null  object
#  25  ADR                          79120 non-null  float64
#  26  RequiredCarParkingSpaces     79120 non-null  int64
#  27  TotalOfSpecialRequests       79120 non-null  object
#  28  ReservationStatus            79120 non-null  object
#  29  ReservationStatusDate        79120 non-null  object
#  30  ArrivalDate                  79120 non-null  object
#  31  ReservationDate              79120 non-null  object
#  32  ChangedRoom                  79120 non-null  int64
#  33  TotalStay                    79120 non-null  float64
#  34  CheckOutDate                 79120 non-null  object
#  35  StayChanges                  79120 non-null  object
#  36  ReservationMonth             79120 non-null  object
# dtypes: float64(7), int64(6), object(24)
# memory usage: 22.9+ MB

# %%
# Creates variable exclusion list for modeling
to_drop = ['ReservationDate', 'ReservationStatusDate', 'CheckOutDate', 
           'ArrivalDate', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth', 
           'ArrivalDateYear', 'AssignedRoomType']

# Removes features
dfo.drop(to_drop, axis=1, inplace=True)

# %%
# Converts all non float variables in categorical
cat_cols = dfo.select_dtypes(exclude='float64').columns
dfo[cat_cols] = dfo[cat_cols].astype('category')

# Convert variables to categorical
dfo['Adults'] = dfo['Adults'].astype('category')
dfo['Children'] = dfo['Children'].astype('category')
dfo['Babies'] = dfo['Babies'].astype('category')

# %% [markdown]
# ## 3.2. Categorical to cardinal transformation

# %%
# Get dummy variables for each categorical variable
df = pd.get_dummies(dfo, drop_first=True)

# Check number of total variables
df.shape
# Out:
# (79120, 95)

# %% [markdown]
# ## 3.3. Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df)
scaled = scaler.transform(df)

# %%
df_scaled = pd.DataFrame(scaled, columns=df.columns)

# %%
df_scaled.sample(10)
# Out:
#        LeadTime  DaysInWaitingList       ADR  TotalStay  \
# 1866   0.073174          -0.154717 -1.190002   0.561835
# 21571  0.019107          -0.154717 -0.435796   0.561835
# 46378 -0.665753          -0.154717  1.146757  -1.081871
# 44232 -0.990161          -0.154717 -0.215926  -1.081871
# 2558  -0.854991          -0.154717 -0.011396   0.561835
# 42387 -0.061995          -0.154717  0.301791   0.561835
# 53311 -0.990161          -0.154717  2.570800  -0.533969
# 60693 -0.107052          -0.154717 -0.521443   0.561835
# 17308 -0.827957          -0.154717  0.602195  -1.081871
# 11555 -0.620697          -0.154717 -0.420457  -1.081871
#
#        ArrivalDateMonth_August  ArrivalDateMonth_December  \
# 1866                  2.797925                  -0.234199
# 21571                -0.357408                   4.269882
# 46378                -0.357408                  -0.234199
# 44232                -0.357408                  -0.234199
# 2558                 -0.357408                  -0.234199
# 42387                -0.357408                   4.269882
# 53311                -0.357408                  -0.234199
# 60693                -0.357408                  -0.234199
# 17308                -0.357408                  -0.234199
# 11555                -0.357408                  -0.234199
#
#        ArrivalDateMonth_February  ArrivalDateMonth_January  \
# 1866                   -0.258338                 -0.222401
# 21571                  -0.258338                 -0.222401
# 46378                  -0.258338                 -0.222401
# 44232                   3.870896                 -0.222401
# 2558                   -0.258338                 -0.222401
# 42387                  -0.258338                 -0.222401
# 53311                  -0.258338                 -0.222401
# 60693                  -0.258338                 -0.222401
# 17308                  -0.258338                 -0.222401
# 11555                  -0.258338                 -0.222401
#
#        ArrivalDateMonth_July  ArrivalDateMonth_June  ...  \
# 1866               -0.336856              -0.332701  ...
# 21571              -0.336856              -0.332701  ...
# 46378              -0.336856              -0.332701  ...
# 44232              -0.336856              -0.332701  ...
# 2558               -0.336856              -0.332701  ...
# 42387              -0.336856              -0.332701  ...
# 53311               2.968623              -0.332701  ...
# 60693              -0.336856              -0.332701  ...
# 17308              -0.336856              -0.332701  ...
# 11555              -0.336856              -0.332701  ...
#
#        ReservationMonth_December  ReservationMonth_February  \
# 1866                   -0.298173                  -0.358037
# 21571                  -0.298173                  -0.358037
# 46378                  -0.298173                   2.793007
# 44232                  -0.298173                   2.793007
# 2558                   -0.298173                  -0.358037
# 42387                  -0.298173                  -0.358037
# 53311                  -0.298173                  -0.358037
# 60693                  -0.298173                  -0.358037
# 17308                  -0.298173                  -0.358037
# 11555                  -0.298173                  -0.358037
#
#        ReservationMonth_January  ReservationMonth_July  ReservationMonth_June  \
# 1866                  -0.395907              -0.311496              -0.213524
# 21571                 -0.395907              -0.311496              -0.213524
# 46378                 -0.395907              -0.311496              -0.213524
# 44232                 -0.395907              -0.311496              -0.213524
# 2558                  -0.395907              -0.311496              -0.213524
# 42387                 -0.395907              -0.311496              -0.213524
# 53311                 -0.395907               3.210310              -0.213524
# 60693                 -0.395907               3.210310              -0.213524
# 17308                 -0.395907              -0.311496              -0.213524
# 11555                 -0.395907              -0.311496              -0.213524
#
#        ReservationMonth_March  ReservationMonth_May  \
# 1866                -0.294489             -0.264792
# 21571               -0.294489             -0.264792
# 46378               -0.294489             -0.264792
# 44232               -0.294489             -0.264792
# 2558                -0.294489             -0.264792
# 42387               -0.294489             -0.264792
# 53311               -0.294489             -0.264792
# 60693               -0.294489             -0.264792
# 17308               -0.294489             -0.264792
# 11555               -0.294489             -0.264792
#
#        ReservationMonth_November  ReservationMonth_October  \
# 1866                   -0.295981                 -0.335879
# 21571                  -0.295981                 -0.335879
# 46378                  -0.295981                 -0.335879
# 44232                  -0.295981                 -0.335879
# 2558                   -0.295981                 -0.335879
# 42387                  -0.295981                 -0.335879
# 53311                  -0.295981                 -0.335879
# 60693                  -0.295981                 -0.335879
# 17308                  -0.295981                 -0.335879
# 11555                  -0.295981                 -0.335879
#
#        ReservationMonth_September
# 1866                    -0.267379
# 21571                    3.740012
# 46378                   -0.267379
# 44232                   -0.267379
# 2558                    -0.267379
# 42387                    3.740012
# 53311                   -0.267379
# 60693                   -0.267379
# 17308                    3.740012
# 11555                   -0.267379
#
# [10 rows x 95 columns]

# %% [markdown]
# ---
# The resulting dataframe is loaded in a csv file for further steps in a different notebook.

# %%
# Writing df dataframe to csv

path1 = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/processed/preprocessed.csv'
path2 = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/processed/non_preprocessed.csv'

df_scaled.to_csv(path1)
dfo.to_csv(path2)

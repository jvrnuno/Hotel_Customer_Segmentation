# %% [markdown]
# # 3. Preprocessing

# %% [markdown]
# 1. Import packages and dataset
# 2. Sample selection
# 3. Categorical to cardinal transformation
# 4. Feature scaling

# %% [markdown]
# ---
# ## 3.1. Import packages and dataset

# %%
# Import the required packages

import os
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings("ignore")

# %%
# Import pre-processed dataset and load it into a dataframe

# Create path variable
original_file = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/interim/category_transformation.csv'

# Load csv in dataframe
dfo = pd.read_csv(original_file, index_col=0)

# %%
# Check # of columns and rows imported
dfo.shape
# Out:
# (78547, 37)

# %%
# Print info
dfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78547 entries, 0 to 79329
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   LeadTime                     78547 non-null  float64
#  1   ArrivalDateYear              78547 non-null  int64
#  2   ArrivalDateMonth             78547 non-null  object
#  3   ArrivalDateWeekNumber        78547 non-null  int64
#  4   ArrivalDateDayOfMonth        78547 non-null  int64
#  5   StaysInWeekendNights         78547 non-null  object
#  6   StaysInWeekNights            78547 non-null  object
#  7   Adults                       78547 non-null  float64
#  8   Children                     78547 non-null  float64
#  9   Babies                       78547 non-null  float64
#  10  Meal                         78547 non-null  object
#  11  Country                      78547 non-null  object
#  12  MarketSegment                78547 non-null  object
#  13  DistributionChannel          78547 non-null  object
#  14  IsRepeatedGuest              78547 non-null  int64
#  15  PreviousCancellations        78547 non-null  object
#  16  PreviousBookingsNotCanceled  78547 non-null  object
#  17  ReservedRoomType             78547 non-null  object
#  18  AssignedRoomType             78547 non-null  object
#  19  BookingChanges               78547 non-null  object
#  20  DepositType                  78547 non-null  object
#  21  Agent                        78547 non-null  object
#  22  Company                      78547 non-null  object
#  23  DaysInWaitingList            78547 non-null  float64
#  24  CustomerType                 78547 non-null  object
#  25  ADR                          78547 non-null  float64
#  26  RequiredCarParkingSpaces     78547 non-null  int64
#  27  TotalOfSpecialRequests       78547 non-null  object
#  28  ReservationStatus            78547 non-null  object
#  29  ReservationStatusDate        78547 non-null  object
#  30  ArrivalDate                  78547 non-null  object
#  31  ReservationDate              78547 non-null  object
#  32  ChangedRoom                  78547 non-null  int64
#  33  TotalStay                    78547 non-null  float64
#  34  CheckOutDate                 78547 non-null  object
#  35  StayChanges                  78547 non-null  object
#  36  ReservationMonth             78547 non-null  object
# dtypes: float64(7), int64(6), object(24)
# memory usage: 22.8+ MB

# %%
# Converts all non float variables in categorical
cat_cols = dfo.select_dtypes(exclude='float64').columns
dfo[cat_cols] = dfo[cat_cols].astype('category')

# Convert variables to categorical
dfo['Adults'] = dfo['Adults'].astype('category')
dfo['Children'] = dfo['Children'].astype('category')
dfo['Babies'] = dfo['Babies'].astype('category')

# %% [markdown]
# ---
# ## 3.2. Sample selection
#
# In this section we will take a reduced sample of the whole dataset for computation feasibility purposes. There are ~80,000 observations which make very time-consuming to run different tests with different clustering algorithms. Therefore, our approach will be to select 20% of the rows in the dataset stratifying them by the variable _ArrivalDateMonth_ to get the most representative sample as possible.
#
# Similarly, there are 37 variables in the original dataset, which some of them are not relevant for the customer segmentation analysis. Those irrelevant variables are related with hotel processes rather than customer choices.

# %%
# Creates variable exclusion list for modeling
to_drop = ['ReservationDate', 'ReservationStatusDate', 'CheckOutDate', 
           'ArrivalDate', 'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth', 
           'ArrivalDateYear', 'AssignedRoomType', 'DaysInWaitingList', 'TotalStay']

# Removes features
dfo.drop(to_drop, axis=1, inplace=True)

# %%
# Selects stratifier variable and 
X = dfo.drop(['ArrivalDateMonth'], axis=1)
y = dfo['ArrivalDateMonth']

# Creates a generator for a stratified random shuffled sample of 20% of observations 
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45)
split = sss.split(X, y)

# Selects sample dataset from split generator
for train_index, test_index in split:
    sample_df = dfo.iloc[test_index]

# %%
# Shows the resulting sample size
sample_df.shape
# Out:
# (15710, 27)

# %% [markdown]
# ---
# ## 3.3. Categorical to cardinal transformation
#
# In present section, we will encode all categories with numeric variables to prepare the dataset for the scaling step. We will assign a new variable for each category but one to avoid colinearity.

# %%
# Get dummy variables for each categorical variable
encoded_df = pd.get_dummies(sample_df, drop_first=True)

# Check number of total variables
encoded_df.shape
# Out:
# (15710, 91)

# %% [markdown]
# We can see that we end up with 91 variables in a very sparse dataset

# %% [markdown]
# ---
# ## 3.4. Feature scaling
#
# Finally, we will scale the whole dataset so all variables have a mean of 0 and a variance of 1

# %%
# Initialized the scaler
scaler = StandardScaler()
# Fit anf transform
scaler.fit(encoded_df)
scaled = scaler.transform(encoded_df)

# %%
# Creates dataframe with the scaled dataset
df_scaled = pd.DataFrame(scaled, columns=encoded_df.columns)

# %%
# Shows a sample of the final dataset
df_scaled.sample(10)
# Out:
#        LeadTime       ADR  ArrivalDateMonth_August  ArrivalDateMonth_December  \
# 5116   0.409272  0.753965                 2.799245                  -0.234822
# 10414  0.246477 -0.496747                -0.357239                  -0.234822
# 15652  0.798174 -0.394669                -0.357239                  -0.234822
# 160   -0.829785  1.110983                -0.357239                  -0.234822
# 5282  -0.576547  0.484734                 2.799245                  -0.234822
# 14583  2.100541 -1.109216                -0.357239                  -0.234822
# 8551   0.680599 -0.670280                -0.357239                   4.258544
# 404    0.174123  0.547002                -0.357239                  -0.234822
# 8271   0.183167 -0.139474                -0.357239                  -0.234822
# 15169 -0.241911 -1.259781                -0.357239                  -0.234822
#
#        ArrivalDateMonth_February  ArrivalDateMonth_January  \
# 5116                   -0.258917                 -0.222963
# 10414                  -0.258917                 -0.222963
# 15652                  -0.258917                 -0.222963
# 160                    -0.258917                 -0.222963
# 5282                   -0.258917                 -0.222963
# 14583                  -0.258917                 -0.222963
# 8551                   -0.258917                 -0.222963
# 404                    -0.258917                 -0.222963
# 8271                   -0.258917                 -0.222963
# 15169                  -0.258917                 -0.222963
#
#        ArrivalDateMonth_July  ArrivalDateMonth_June  ArrivalDateMonth_March  \
# 5116               -0.335686              -0.332862               -0.297325
# 10414               2.978975              -0.332862               -0.297325
# 15652              -0.335686              -0.332862               -0.297325
# 160                -0.335686              -0.332862               -0.297325
# 5282               -0.335686              -0.332862               -0.297325
# 14583              -0.335686              -0.332862               -0.297325
# 8551               -0.335686              -0.332862               -0.297325
# 404                -0.335686               3.004251               -0.297325
# 8271               -0.335686              -0.332862               -0.297325
# 15169              -0.335686              -0.332862               -0.297325
#
#        ArrivalDateMonth_May  ...  ReservationMonth_December  \
# 5116              -0.339896  ...                  -0.301365
# 10414             -0.339896  ...                  -0.301365
# 15652             -0.339896  ...                  -0.301365
# 160               -0.339896  ...                  -0.301365
# 5282              -0.339896  ...                  -0.301365
# 14583             -0.339896  ...                  -0.301365
# 8551              -0.339896  ...                  -0.301365
# 404               -0.339896  ...                  -0.301365
# 8271              -0.339896  ...                   3.318238
# 15169             -0.339896  ...                  -0.301365
#
#        ReservationMonth_February  ReservationMonth_January  \
# 5116                    2.786010                 -0.397545
# 10414                   2.786010                 -0.397545
# 15652                   2.786010                 -0.397545
# 160                    -0.358936                 -0.397545
# 5282                   -0.358936                 -0.397545
# 14583                  -0.358936                 -0.397545
# 8551                   -0.358936                 -0.397545
# 404                    -0.358936                  2.515437
# 8271                   -0.358936                 -0.397545
# 15169                  -0.358936                 -0.397545
#
#        ReservationMonth_July  ReservationMonth_June  ReservationMonth_March  \
# 5116               -0.308720              -0.213357               -0.296055
# 10414              -0.308720              -0.213357               -0.296055
# 15652              -0.308720              -0.213357               -0.296055
# 160                -0.308720              -0.213357               -0.296055
# 5282                3.239185              -0.213357               -0.296055
# 14583              -0.308720              -0.213357               -0.296055
# 8551               -0.308720               4.686986               -0.296055
# 404                -0.308720              -0.213357               -0.296055
# 8271               -0.308720              -0.213357               -0.296055
# 15169               3.239185              -0.213357               -0.296055
#
#        ReservationMonth_May  ReservationMonth_November  \
# 5116              -0.262814                  -0.289391
# 10414             -0.262814                  -0.289391
# 15652             -0.262814                  -0.289391
# 160               -0.262814                  -0.289391
# 5282              -0.262814                  -0.289391
# 14583             -0.262814                  -0.289391
# 8551              -0.262814                  -0.289391
# 404               -0.262814                  -0.289391
# 8271              -0.262814                  -0.289391
# 15169             -0.262814                  -0.289391
#
#        ReservationMonth_October  ReservationMonth_September
# 5116                  -0.340129                   -0.267899
# 10414                 -0.340129                   -0.267899
# 15652                 -0.340129                   -0.267899
# 160                   -0.340129                    3.732755
# 5282                  -0.340129                   -0.267899
# 14583                  2.940060                   -0.267899
# 8551                  -0.340129                   -0.267899
# 404                   -0.340129                   -0.267899
# 8271                  -0.340129                   -0.267899
# 15169                 -0.340129                   -0.267899
#
# [10 rows x 91 columns]

# %% [markdown]
# ---
# The resulting dataframe is loaded in a csv file for further steps in a different notebook.

# %%
# Writing df dataframe to csv

path1 = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/processed/preprocessed.csv'
path2 = 'C:/Users/javie/OneDrive/Documents/springboard_projects/Capstone-3/data/processed/non_preprocessed.csv'

df_scaled.to_csv(path1)
sample_df.to_csv(path2)
